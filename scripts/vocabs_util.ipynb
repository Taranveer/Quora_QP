# %%
import numpy as np
import pickle
from collections import Counter
# shared global variables to be imported from model also
UNK = "$UNK$"
NUM = "$NUM$"


class Dataset(object):
    def __init__(self, filename, emb_file):
        self.filename = filename
        self.emb_file = emb_file


    def generate_vocab(self):
        text_vocab = self.get_vocabs()
        emb_vocab = self.get_w2v_vocab()
        self.vocab = text_vocab & emb_vocab
        # self.vocab.add(UNK)
        return self.vocab



    def get_vocabs(self):
        """
        This function just returns the vocabulary in the text
        :return:
        """
        print "Building vocab from text ..."
        with open(self.filename) as f:
            data = pickle.load(f)
            data = data[0]
            data = [x.split() for x in data]
            vocab_words= set()
            for line in data:
                vocab_words.update(line)
            print("- done. {} tokens".format(len(vocab_words)))
        return vocab_words

    def get_w2v_vocab(self):
        """
        This function return the vocabulary we have in the
        word embedding file
        :return:
        """
        print "Building vocab from embeddings ..."
        vocab = set()
        with open(self.emb_file) as f:
            for line in f:
                word = line.strip().split(' ')[0]
                vocab.add(word)
        print("- done. {} tokens".format(len(vocab)))
        return vocab

def write_vocab(vocab, filename):
    """
    Writes a vocab to a file
    :param vocab:
    :param filename:
    :return: write a word per line
    """

    print("Writing vocab...")
    with open(filename, "w") as f:
        for i, word in enumerate(vocab):
            if i != len(vocab) - 1:
                f.write("{}\n".format(word))
            else:
                f.write(word)
    print("- done. {} tokens".format(len(vocab)))

def load_vocab(filename):
    """
    Loads vocab from a file
    :param filename:
    :return: d: dict[word] = index
    """
    try:
        d = dict()
        with open(filename) as f:
            for idx, word in enumerate(f):
                word = word.strip()
                d[word] = idx

    except IOError:
        print "Generate the vocabulary and embeddings first"
    return d


def export_trimmed_w2v_vectors(vocab, glove_filename, trimmed_filename, dim=300):
    """Saves glove vectors in numpy array

    Args:
        vocab: dictionary vocab[word] = index
        glove_filename: a path to a glove file
        trimmed_filename: a path where to store a matrix in npy
        dim: (int) dimension of embeddings

    """
    embeddings = np.zeros([len(vocab), dim])
    with open(glove_filename) as f:
        for line in f:
            line = line.strip().split(' ')
            word = line[0]
            embedding = [float(x) for x in line[1:]]
            if word in vocab:
                word_idx = vocab[word]
                embeddings[word_idx] = np.asarray(embedding)

    np.savez_compressed(trimmed_filename, embeddings=embeddings)


def get_trimmed_w2v_vectors(filename):
    """
    Load embeddings vectors
    :param filename:
    :return:
    """
    try:
        with np.load(filename) as data:
            return data["embeddings"]

    except IOError:
        print "File: %s, NOT FOUND."%(filename)

# %%
# dataset = Dataset("sentences_train_10000.pkl", "../glove.840B.300d.txt")
# dataset.generate_vocab()
# write_vocab(dataset.vocab, "vocab_quora_train.txt")
# vocab = load_vocab("vocab_quora_train.txt")
# export_trimmed_w2v_vectors(vocab, "../glove.840B.300d.txt", "trimmed_embeddings_train_quora.npz")
# glove_array = get_trimmed_w2v_vectors("trimmed_embeddings_train_quora.npz")
# glove_array.shape
# Out:
# Building vocab from text ...
# - done. 17443 tokens
# Building vocab from embeddings ...
# - done. 2196016 tokens
# Writing vocab...
# - done. 16836 tokens
# (16836, 300)

# %%
import pickle
a = pickle.load(open("sentences_train_10000.pkl"))

# %%
import numpy as np
data = np.load("trimmed_embeddings_train_quora.npz")
data["embeddings"][vocab["yellow"]]
# Out:
# array([ -2.49890000e-01,   2.49400000e-01,  -4.85640000e-02,
#         -2.43340000e-01,   3.33380000e-01,  -8.33040000e-02,
#         -4.11020000e-01,  -1.42940000e-01,  -6.68310000e-01,
#          6.69200000e-01,  -2.36680000e-01,  -2.91170000e-01,
#         -1.72890000e-01,  -2.87750000e-01,   2.73950000e-02,
#          1.00810000e-01,   3.77060000e-01,   1.96930000e+00,
#          1.28460000e-01,  -9.41180000e-01,   3.93660000e-01,
#         -5.04500000e-01,  -3.09290000e-01,   2.56340000e-01,
#          7.97100000e-02,  -4.47000000e-01,  -3.25850000e-01,
#         -3.42420000e-01,   3.11050000e-01,  -9.23360000e-02,
#         -2.46230000e-01,   4.64460000e-02,   2.24810000e-01,
#         -2.90690000e-01,  -3.74410000e-01,  -1.30850000e-01,
#          9.29780000e-02,  -1.13270000e-01,   2.56250000e-01,
#         -9.98050000e-02,   5.37940000e-01,   3.41820000e-01,
#         -5.11250000e-02,   1.21520000e-02,   9.17360000e-01,
#         -4.14920000e-01,  -2.32530000e-01,   2.25690000e-01,
#          4.35490000e-01,  -4.57880000e-01,  -4.21010000e-01,
#          1.08220000e-01,   1.37270000e-01,  -1.33630000e-01,
#          2.75420000e-01,  -2.23890000e-01,  -5.07510000e-01,
#          4.74990000e-01,   1.13340000e-01,  -4.78560000e-01,
#         -5.71530000e-01,  -1.34810000e-01,   3.29000000e-01,
#          1.97250000e-01,   9.42200000e-02,   1.37530000e-01,
#         -1.47260000e-01,  -1.35730000e-01,  -2.32290000e-01,
#          6.58400000e-01,  -2.01960000e-01,   2.24630000e-01,
#         -1.80000000e-01,   7.38770000e-03,  -1.29700000e-01,
#          1.17880000e-01,   8.28530000e-02,  -1.64070000e-01,
#          3.30990000e-01,  -2.98370000e-01,  -2.93690000e-01,
#          4.74570000e-01,   7.26510000e-02,   4.33320000e-01,
#          3.62710000e-01,  -4.28990000e-01,   1.40640000e+00,
#          1.15070000e+00,  -5.47070000e-02,  -3.93670000e-02,
#          3.71580000e-01,   1.82210000e-01,   1.03570000e+00,
#         -1.67190000e-01,  -6.11050000e-02,  -1.28950000e-01,
#         -4.02620000e-01,   1.94990000e-02,   9.79680000e-02,
#         -4.54370000e-01,   4.82040000e-01,   6.73120000e-02,
#          3.98100000e-01,  -4.79750000e-01,  -3.07080000e-01,
#         -5.57430000e-01,  -7.60080000e-01,   4.12040000e-01,
#          2.23200000e-01,   6.40320000e-01,  -5.13140000e-01,
#         -1.50090000e-01,   1.57530000e-01,   2.34170000e-01,
#          2.29160000e-01,   8.93810000e-02,   8.16380000e-02,
#         -1.85740000e-01,   6.39390000e-02,   5.19220000e-02,
#         -4.00870000e-01,  -1.87160000e-01,  -3.30380000e-01,
#         -2.72020000e-01,  -2.69680000e-01,   2.50770000e-01,
#          4.52990000e-01,  -1.09090000e-01,   3.99490000e-02,
#         -2.18330000e-01,  -3.99660000e-01,   3.28150000e-02,
#         -1.57160000e-01,  -8.43230000e-02,   1.21210000e-01,
#         -3.36480000e-01,   1.07670000e-01,  -3.43410000e-01,
#          7.18090000e-02,   2.55080000e-01,  -2.34030000e+00,
#          4.41920000e-01,   4.38010000e-01,   1.00980000e-01,
#         -8.51350000e-02,   2.33410000e-01,  -3.43480000e-01,
#          2.02920000e-01,   1.76430000e-01,   1.78470000e-01,
#          2.97320000e-01,   1.47880000e-01,   5.38400000e-01,
#         -2.47100000e-01,  -4.51800000e-01,  -2.63320000e-01,
#         -7.65470000e-01,   2.42670000e-01,  -3.84210000e-01,
#          7.37990000e-02,  -1.70750000e-01,  -2.11800000e-01,
#          1.30750000e-01,   1.84220000e-01,   5.94090000e-01,
#         -4.69830000e-01,  -3.83670000e-01,  -1.05350000e-01,
#          3.00560000e-02,   1.99390000e-01,  -2.89180000e-01,
#          2.25490000e-01,  -5.23750000e-01,  -1.13560000e-01,
#         -3.40440000e-01,  -2.18940000e-01,   2.92670000e-01,
#         -3.12490000e-02,   3.61190000e-01,   2.88720000e-01,
#         -6.44130000e-02,   9.94520000e-02,  -5.81290000e-02,
#         -2.27090000e-01,   1.85070000e-02,  -7.62530000e-02,
#         -8.49070000e-01,  -2.11220000e-01,  -2.66780000e-01,
#         -2.38800000e-01,   3.87530000e-01,   1.90520000e-01,
#          2.43400000e-01,  -1.57410000e-02,   1.97480000e-01,
#          9.95490000e-02,   4.04690000e-01,   4.04380000e-01,
#         -3.33760000e-01,   8.90540000e-02,  -1.88990000e-01,
#         -8.37300000e-02,  -5.50960000e-01,   1.23390000e-01,
#          2.61270000e-01,   6.35340000e-02,   6.40600000e-01,
#         -6.87330000e-01,   7.53160000e-02,   4.14180000e-01,
#          3.59430000e-01,   6.36480000e-01,   3.20290000e-01,
#          1.81990000e-02,  -9.46240000e-02,   2.63080000e-01,
#         -2.56200000e-01,  -2.45430000e-01,   2.42040000e-01,
#         -2.96310000e-01,  -3.54480000e-01,  -2.84610000e-01,
#          1.01310000e-02,   3.61900000e-02,  -2.26160000e-01,
#          5.97100000e-02,   4.38790000e-01,   2.04610000e-01,
#         -7.36820000e-02,   2.13820000e-01,   5.80060000e-03,
#          5.78820000e-01,   1.47640000e-01,   5.93980000e-01,
#          3.00800000e-01,   4.31550000e-01,   7.52370000e-02,
#          3.22560000e-02,   7.05830000e-01,   8.63480000e-01,
#         -3.22970000e-01,   1.73880000e-01,  -6.24750000e-01,
#         -1.18160000e-01,  -3.12640000e-01,   1.22190000e-01,
#          2.59870000e-01,  -2.09940000e-01,  -1.74770000e-01,
#          7.23510000e-02,  -2.84120000e-02,  -5.38080000e-02,
#         -1.03630000e-01,   2.13440000e-01,   2.71680000e-01,
#          4.10620000e-01,   3.74920000e-01,   3.18820000e-01,
#         -3.42430000e-03,   1.42920000e-01,   1.00350000e-01,
#         -7.70850000e-02,  -5.11580000e-03,   5.56750000e-01,
#         -8.89140000e-02,   2.58190000e-01,  -1.25870000e-01,
#         -2.04170000e-01,  -4.60670000e-01,   4.93090000e-02,
#         -2.06670000e-01,   1.73380000e-03,  -2.24340000e-01,
#         -1.06230000e-01,  -8.21110000e-02,  -5.33490000e-01,
#         -2.46340000e-01,   4.94340000e-01,  -5.50310000e-02,
#          1.54210000e-01,  -8.51620000e-02,  -1.79050000e-01,
#         -4.25440000e-01,  -3.91010000e-01,  -1.63510000e-01,
#          1.46900000e-01,  -2.21000000e-02,   4.10190000e-01,
#          7.85760000e-01,  -3.51240000e-01,  -4.41450000e-01,
#          2.44060000e-01,   3.85430000e-01,  -2.76470000e-01,
#         -3.00080000e-01,   5.54740000e-01,   1.41310000e-01,
#         -4.59350000e-01,   3.06330000e-01,   8.24630000e-01])

# %%
vocab = load_vocab("vocab_quora_train.txt")

# %%
vocab
# Out:
# {'mohini': 0,
#  'Duncan': 13910,
#  'unscientific': 1,
#  'writings': 2,
#  'Szczecin': 3,
#  'childern': 4,
#  'yellow': 5,
#  'Sugar': 6,
#  'four': 7,
#  'prefix': 8,
#  'Does': 9,
#  'Olympics': 10,
#  'spiders': 11,
#  'ornate': 66,
#  'centimeter': 14,
#  'Until': 15,
#  'aggression': 16,
#  'Foundation': 101,
#  'granting': 18,
#  'eligible': 19,
#  'electricity': 20,
#  'adviced': 21,
#  'unanswered': 22,
#  'wheeled': 23,
#  'Ronald': 24,
#  'SPI': 25,
#  'outwit': 26,
#  'Belgians': 27,
#  'Western': 28,
#  'Climbing': 30,
#  'Avada': 31,
#  'Euro': 32,
#  'sinking': 33,
#  'digit': 34,
#  'Airprint': 36,
#  'oceans': 37,
#  'Www': 11035,
#  'experimentally': 40,
#  'cobia': 41,
#  'bringing': 42,
#  'lumia': 43,
#  'Comlete': 44,
#  'differentiated': 45,
#  'basics': 46,
#  'internally': 47,
#  'scholar': 48,
#  'JNU': 49,
#  'Less': 50,
#  'wooden': 51,
#  'CGPA': 52,
#  'unblurred': 53,
#  'HDFC': 54,
#  'Nasdaq': 55,
#  'differentiates': 56,
#  'deferments': 58,
#  'Paul': 59,
#  'employee': 16355,
#  'straight': 2705,
#  'Sandy': 61,
#  'Omegle': 62,
#  'Rachel': 11042,
#  'specially': 64,
#  'tired': 65,
#  'hanging': 12,
#  'bacon': 67,
#  'pulse': 68,
#  'budget': 69,
#  '270': 70,
#  'A53': 71,
#  'cyclic': 15253,
#  'valiant': 72,
#  'sailed': 74,
#  'Pichai': 75,
#  'inanimate': 76,
#  'Sapiens': 77,
#  'errors': 79,
#  'Sapient': 80,
#  'thunder': 81,
#  'cooking': 82,
#  'contributed': 83,
#  'fingers': 84,
#  'victims': 85,
#  'gujarati': 86,
#  'ms': 12621,
#  'usenet': 87,
#  'fossil': 88,
#  'designing': 89,
#  'resilient': 90,
#  'replaced': 11048,
#  'H1B': 92,
#  'Raspberry': 93,
#  'Ichigo': 94,
#  'Presidential': 95,
#  'shocks': 96,
#  'specialist': 98,
#  'hero': 100,
#  'offenses': 10549,
#  'Freenet': 5409,
#  'Branch': 8960,
#  'splinter': 623,
#  'asteroids': 13281,
#  'brainwashed': 104,
#  'here': 105,
#  'atoms': 106,
#  'reported': 107,
#  'GRE': 108,
#  'Siliguri': 109,
#  'cult': 110,
#  'evolutionist': 111,
#  'corrections': 12843,
#  'Stephanie': 112,
#  'chaotic': 12098,
#  'kids': 113,
#  'unblocked': 114,
#  'chlorides': 115,
#  'Record': 13898,
#  'k': 117,
#  'adaptable': 16823,
#  'reports': 118,
#  'Hamas': 119,
#  'electors': 11651,
#  'tortoiseshell': 122,
#  'NOT': 123,
#  'military': 124,
#  'Hydrogen': 125,
#  'cancellation': 126,
#  'NOR': 127,
#  'Audi': 128,
#  'golden': 129,
#  'Awakens': 130,
#  'divide': 131,
#  'gluons': 132,
#  'criticise': 133,
#  'Harvey': 134,
#  'explained': 136,
#  'Three': 137,
#  'ProActiv': 138,
#  'replace': 139,
#  'psychological': 140,
#  'unix': 141,
#  'Wales': 142,
#  'Basin': 143,
#  'cocaine': 144,
#  'univ': 145,
#  'unit': 146,
#  'Nangloi': 147,
#  'derivatives': 149,
#  'cheating': 150,
#  'Sagittarius': 151,
#  'browse': 152,
#  '42': 12370,
#  '1210': 14248,
#  'Grian': 930,
#  'therefore': 154,
#  'AngularJS': 155,
#  'menthol': 15191,
#  'strike': 156,
#  'mAh': 157,
#  'Flipkart': 13905,
#  'until': 158,
#  'expiring': 159,
#  'playboy': 160,
#  'females': 161,
#  'Christine': 162,
#  'successful': 163,
#  'brings': 164,
#  'hereby': 165,
#  'underprivileged': 14807,
#  'yahoo': 167,
#  'hurt': 168,
#  '99': 169,
#  'glass': 170,
#  'reversible': 172,
#  'Tunak': 173,
#  'lord': 174,
#  '91': 175,
#  '90': 176,
#  'hole': 177,
#  'hold': 178,
#  '95': 179,
#  '94': 180,
#  '97': 181,
#  'circumstances': 182,
#  'morally': 184,
#  'Indigo': 185,
#  'pursue': 186,
#  'Text': 187,
#  'blade': 188,
#  'Luna': 189,
#  'imperialism': 11060,
#  'temperatures': 191,
#  'Malaysians': 192,
#  'concepts': 193,
#  'exhale': 194,
#  'shaving': 195,
#  'example': 196,
#  'impose': 8003,
#  'wand': 198,
#  'Quang': 1176,
#  'household': 201,
#  'artillery': 202,
#  'organized': 203,
#  'Reality': 204,
#  'currency': 205,
#  'ABAP': 206,
#  'Bike': 207,
#  'Quant': 208,
#  'want': 210,
#  'Udaipur': 211,
#  'organizer': 212,
#  'Oberon': 213,
#  'absolute': 214,
#  'Julien': 15179,
#  'LG': 215,
#  'hoc': 216,
#  'unpaid': 13913,
#  'mission': 14907,
#  'travel': 219,
#  'feature': 220,
#  'machine': 221,
#  'how': 222,
#  'methodology': 223,
#  'playback': 224,
#  'LR': 225,
#  'hop': 226,
#  'significance': 227,
#  'Krishnamurti': 229,
#  'activation': 6801,
#  'Certified': 231,
#  'Zika': 232,
#  'A': 233,
#  'tripling': 234,
#  'abstraction': 235,
#  'Bates': 236,
#  'beauty': 237,
#  'cuisine': 238,
#  'modulation': 239,
#  'typed': 240,
#  'cuss': 3325,
#  'outlawed': 241,
#  'diagram': 242,
#  'dinosaurs': 243,
#  'wrong': 244,
#  'L2': 245,
#  'destined': 246,
#  'types': 247,
#  'CFO': 248,
#  'CFL': 249,
#  'effective': 251,
#  'wins': 252,
#  'attracts': 253,
#  'Tumblr': 13912,
#  'fictional': 254,
#  'CFA': 255,
#  'baggage': 256,
#  '18th': 257,
#  'specks': 258,
#  'keeps': 259,
#  'Shimon': 260,
#  'democratic': 261,
#  'mightier': 11311,
#  'wing': 262,
#  'wind': 263,
#  'wine': 264,
#  'Monterrey': 265,
#  'Even': 5435,
#  'afterwards': 14208,
#  'feedback': 267,
#  'telecom': 268,
#  'dreamed': 269,
#  'Blackstone': 270,
#  'confederate': 8203,
#  'vary': 272,
#  'fallacies': 274,
#  'intangible': 276,
#  'Robertson': 277,
#  'activating': 279,
#  'Told': 280,
#  'PARTNERS': 281,
#  'Abbott': 282,
#  'His': 283,
#  'ligand': 284,
#  'Kearns': 285,
#  'rankings': 286,
#  'fix': 287,
#  '624': 5441,
#  'Tandon': 288,
#  'survivors': 289,
#  'Harris': 290,
#  'hidden': 291,
#  'easier': 292,
#  'ledgers': 293,
#  'blowjobs': 294,
#  'thrones': 295,
#  'enrich': 296,
#  '2030': 297,
#  'Seth': 298,
#  'Volvo': 299,
#  'commemorate': 300,
#  'effects': 301,
#  'schools': 302,
#  'silver': 303,
#  'structural': 304,
#  'rumour': 305,
#  'represents': 306,
#  'socialization': 14796,
#  'PPACA': 307,
#  'Shield': 308,
#  'APJ': 311,
#  'APK': 312,
#  'API': 313,
#  'component': 13086,
#  'averse': 315,
#  'APM': 316,
#  'addicted': 317,
#  'volcano': 318,
#  'Farsi': 319,
#  'safely': 16467,
#  'burial': 321,
#  'Falklands': 322,
#  'financial': 323,
#  'snakes': 324,
#  'woes': 325,
#  'mdm': 326,
#  'series': 327,
#  'liquids': 15445,
#  'displacement': 328,
#  'Mongolia': 329,
#  '391': 330,
#  'passwords': 11081,
#  'DCX3400': 332,
#  'laboratory': 333,
#  'rarest': 15915,
#  'ring': 335,
#  'overwrite': 336,
#  'disposed': 14521,
#  'Gustav': 337,
#  'trending': 338,
#  'Kenya': 16676,
#  'rs': 340,
#  'Retina': 341,
#  'sms': 342,
#  'angular': 5455,
#  're': 344,
#  'encourage': 345,
#  'Hercules': 8216,
#  'adapt': 347,
#  'Rabbit': 348,
#  'Entrepreneurs': 2749,
#  'size': 5456,
#  'Super': 351,
#  'foundation': 352,
#  'Word': 353,
#  'University': 355,
#  'Work': 356,
#  'surveys': 13941,
#  'managerial': 358,
#  '4620': 359,
#  'Qualcomm': 360,
#  'necessarily': 13942,
#  'Pension': 362,
#  'Mature': 363,
#  'sheet': 5459,
#  'sensors': 366,
#  'Pakistanis': 367,
#  'cornerstone': 368,
#  'r5': 369,
#  'ate': 370,
#  'Rosenberg': 371,
#  'diabetic': 372,
#  'kashmir': 373,
#  'ath': 375,
#  'heading': 8221,
#  'silicon': 377,
#  'shipped': 378,
#  'Human': 379,
#  'kingdom': 14399,
#  'repealed': 380,
#  'symbolize': 381,
#  'speeds': 382,
#  'purpose': 11089,
#  'Universities': 383,
#  'Voter': 385,
#  'Dun': 387,
#  'Duo': 388,
#  'Duc': 391,
#  'Please': 392,
#  'vitro': 393,
#  'Swg': 394,
#  'OWASP': 395,
#  'channels': 396,
#  'wash': 397,
#  'instruct': 398,
#  'IPV4': 399,
#  'Coursera': 16240,
#  'wasn': 400,
#  'clarity': 401,
#  '173': 402,
#  '172': 403,
#  '170': 404,
#  'bitten': 405,
#  'olds': 406,
#  'backlinks': 407,
#  'service': 408,
#  'lego': 409,
#  'engagement': 410,
#  'URINE': 411,
#  'Effect': 412,
#  'needed': 413,
#  'master': 414,
#  'listed': 415,
#  'hypothetical': 416,
#  'worlds': 16065,
#  'postulate': 417,
#  'legs': 418,
#  'bitter': 419,
#  'listen': 421,
#  'rectifier': 422,
#  'collapse': 423,
#  'canned': 424,
#  'cushions': 425,
#  'convention': 13954,
#  'coursera': 427,
#  'satisfaction': 14218,
#  'wisdom': 429,
#  'Date': 13955,
#  'oblongata': 432,
#  'legally': 13956,
#  'Oracle': 434,
#  'Vancouver': 16783,
#  'Daddy': 435,
#  'Deepwater': 13957,
#  'Kaine': 437,
#  'trek': 438,
#  'Code': 439,
#  'Pvt': 440,
#  'Chloe': 441,
#  'SPAM': 442,
#  'coward': 443,
#  'tree': 444,
#  'second': 445,
#  'nations': 446,
#  'shower': 447,
#  'pneumonia': 448,
#  'idle': 449,
#  'Maxis': 450,
#  'Tape': 8232,
#  'Capricorns': 453,
#  'feeling': 454,
#  'acquisition': 456,
#  'Angelo': 457,
#  'etihad': 458,
#  'entail': 459,
#  'Evasion': 460,
#  'Chicago': 461,
#  'boston': 462,
#  'Sumter': 463,
#  'spectrum': 464,
#  'Gatorade': 465,
#  'increment': 466,
#  'urinate': 467,
#  'H1b': 468,
#  'Williams': 469,
#  'CLI': 13963,
#  'Then': 471,
#  'Them': 472,
#  'recommender': 473,
#  'Portability': 7758,
#  'hymen': 475,
#  'concrete': 5428,
#  'responsible': 2777,
#  'phase': 12485,
#  'GSoC': 478,
#  'Band': 479,
#  'recommended': 480,
#  'causing': 481,
#  'absorbed': 482,
#  'Minister': 483,
#  'They': 484,
#  'brains': 5475,
#  'Ask': 486,
#  'Ash': 487,
#  'Bank': 488,
#  'Names': 489,
#  'Jones': 490,
#  'VCA': 491,
#  'committing': 492,
#  'transactions': 494,
#  'thrilled': 495,
#  'advanced': 15491,
#  'object': 496,
#  'Havarti': 8239,
#  'Rajesh': 498,
#  'metrics': 499,
#  'simplify': 500,
#  'mouth': 501,
#  'letter': 503,
#  'Gujarat': 504,
#  'gmail': 16377,
#  'thriller': 506,
#  'morality': 507,
#  'singer': 508,
#  'episode': 509,
#  'antitrust': 510,
#  'professor': 511,
#  'camp': 512,
#  'N52': 513,
#  'VCs': 515,
#  'tech': 516,
#  'euthanize': 517,
#  'mating': 518,
#  'scream': 519,
#  'came': 520,
#  'marvel': 521,
#  'saying': 522,
#  'bomb': 523,
#  'reactor': 524,
#  'Union': 525,
#  'Abdul': 526,
#  'meetings': 527,
#  'advisors': 528,
#  'sexist': 529,
#  'soluble': 530,
#  'ulcer': 532,
#  'participate': 533,
#  'lethal': 534,
#  'heckled': 535,
#  'driving': 12792,
#  'Bhopal': 537,
#  'lessons': 538,
#  'touches': 539,
#  'busy': 540,
#  'Premium': 541,
#  'BPMN': 542,
#  'menu': 543,
#  'rheostat': 545,
#  'Kedavra': 12429,
#  '1549': 546,
#  'Translator': 547,
#  'cougar': 548,
#  'theme': 549,
#  'Stripe': 550,
#  'rich': 551,
#  'rice': 553,
#  'Timor': 554,
#  'plate': 556,
#  'salespeople': 557,
#  'cubic': 12127,
#  'Jinnah': 558,
#  'umbilical': 559,
#  'foremost': 560,
#  'pocket': 561,
#  'fetish': 8253,
#  'momentums': 564,
#  'X': 565,
#  'Piece': 566,
#  'net': 8254,
#  'VoLTE': 568,
#  'increasing': 569,
#  'autistic': 570,
#  'nicely': 571,
#  'wickless': 572,
#  'ZEE': 573,
#  'Rip': 575,
#  'patch': 576,
#  'Rio': 577,
#  'Pentium': 12975,
#  'excaliber': 578,
#  'release': 580,
#  'transistors': 581,
#  'saul': 583,
#  'respond': 584,
#  'pople': 585,
#  'mandatory': 586,
#  'fair': 587,
#  'Dogg': 589,
#  'peripheral': 590,
#  'mysql': 591,
#  'Devops': 592,
#  'transferred': 5493,
#  'unexpectedly': 594,
#  'bled': 595,
#  'Mahendra': 596,
#  'DMS': 597,
#  'counries': 598,
#  'result': 599,
#  'DMV': 600,
#  'fail': 601,
#  'Olympiad': 602,
#  'Android': 603,
#  'John': 604,
#  'Dogs': 605,
#  'best': 606,
#  'reassignment': 5496,
#  'Emojis': 11121,
#  'lots': 609,
#  'Tumnus': 16568,
#  'rings': 610,
#  'Batch': 15234,
#  'stamps': 612,
#  'score': 613,
#  'Cbse': 614,
#  'yogurt': 615,
#  'Terrier': 616,
#  'pirate': 617,
#  'Advanced': 618,
#  'skimpy': 619,
#  'requisites': 620,
#  'letting': 9826,
#  'lamar': 622,
#  'men': 15993,
#  'extend': 624,
#  'nature': 625,
#  'rolled': 626,
#  'Hike': 627,
#  'personalize': 628,
#  'rides': 12956,
#  'Guwahati': 5500,
#  'eukaryotic': 630,
#  'Uncharted': 631,
#  'extent': 632,
#  'Sartre': 633,
#  'downgrade': 634,
#  'carbon': 635,
#  'debt': 636,
#  'dslr': 11127,
#  'pity': 638,
#  'patented': 639,
#  'accident': 640,
#  'country': 642,
#  'adapter': 643,
#  'enlightenment': 13211,
#  'heating': 644,
#  'demanded': 645,
#  '109': 8268,
#  'Object': 15765,
#  'planned': 647,
#  'logic': 648,
#  'ASUS': 649,
#  'login': 650,
#  'argue': 651,
#  'adapted': 652,
#  'asked': 653,
#  'PSU': 654,
#  'pre': 14001,
#  'Completeness': 658,
#  'HND': 659,
#  'Montag': 660,
#  'BCA': 661,
#  '2nd': 662,
#  'matte': 663,
#  'Ohio': 8271,
#  'pregnancy': 666,
#  'diff': 667,
#  '250': 668,
#  'angel': 5509,
#  'shouting': 11133,
#  'union': 671,
#  'Targaryens': 672,
#  'subside': 673,
#  'perchlorate': 674,
#  'economically': 12838,
#  'bothers': 675,
#  'extraction': 676,
#  'much': 677,
#  'sommelier': 678,
#  'tutorials': 679,
#  'superhuman': 680,
#  'Flowers': 681,
#  'tallest': 682,
#  'dots': 683,
#  'obese': 684,
#  'life': 685,
#  'crying': 686,
#  'spit': 687,
#  'SRE': 688,
#  'BPM': 14006,
#  'Poland': 690,
#  'worker': 691,
#  'Ketogenic': 692,
#  'snap': 11140,
#  'substance': 694,
#  'chile': 695,
#  'child': 696,
#  'fattiest': 697,
#  'worked': 698,
#  'Waffen': 5515,
#  'spin': 700,
#  'cum': 11142,
#  'Holmes': 4094,
#  'commerce': 703,
#  'adaptations': 704,
#  'presidency': 705,
#  '25M': 706,
#  'submissions': 707,
#  'technologically': 15224,
#  'professionally': 708,
#  'excited': 11143,
#  'employ': 710,
#  'calcium': 711,
#  'Spacecraft': 712,
#  'forwarder': 5978,
#  'prostrate': 715,
#  'flooding': 716,
#  'skirts': 717,
#  'remembering': 718,
#  'biotech': 719,
#  'Lindenwood': 4185,
#  'played': 721,
#  'equator': 722,
#  'FHD': 723,
#  'expat': 724,
#  'reunified': 11147,
#  'Painters': 726,
#  'player': 727,
#  'elicit': 728,
#  'Capitan': 4246,
#  'EB2': 730,
#  'levied': 731,
#  'conditioner': 4259,
#  'Nougat': 733,
#  'Riemann': 11148,
#  'hone': 734,
#  'damaged': 735,
#  'Main': 5524,
#  'severity': 737,
#  'NetSuite': 738,
#  'Python': 739,
#  'things': 740,
#  'toaster': 741,
#  'Kerman': 13002,
#  'dryness': 14017,
#  'democracies': 743,
#  'craigslist': 744,
#  '300': 11219,
#  'split': 745,
#  'babies': 746,
#  'Amelia': 747,
#  'Retriever': 4360,
#  'H3C': 750,
#  'Budapest': 751,
#  'boiled': 752,
#  'countable': 15184,
#  'qualifications': 4390,
#  'eradicate': 755,
#  'Angeles': 756,
#  'ownership': 758,
#  'wives': 760,
#  'tune': 761,
#  'intrusion': 763,
#  'matters': 11154,
#  'blowjob': 11155,
#  'EBT': 765,
#  'academic': 766,
#  'academia': 767,
#  'Goodreads': 16530,
#  'EBS': 768,
#  'quantitative': 769,
#  'corporate': 770,
#  'massaging': 771,
#  'lazer': 7302,
#  'opinions': 772,
#  'gigolo': 4548,
#  'Thank': 774,
#  'sleeps': 775,
#  'dietetics': 777,
#  'distribute': 778,
#  'sleepy': 4580,
#  'VBA': 8291,
#  'UPES': 781,
#  'financially': 782,
#  'Native': 8945,
#  'rotates': 784,
#  'portrayed': 785,
#  'previous': 786,
#  'hai': 787,
#  'enters': 788,
#  'dialogues': 789,
#  'ham': 790,
#  'dining': 14025,
#  'had': 793,
#  'Leonard': 795,
#  'XBOX': 796,
#  'Connecticut': 797,
#  'collections': 798,
#  'easy': 799,
#  'prison': 800,
#  'has': 4725,
#  'hat': 802,
#  'Apart': 803,
#  'Roadies': 804,
#  'municipal': 805,
#  'elders': 806,
#  'survival': 807,
#  'online': 5535,
#  'disagreement': 809,
#  'possible': 810,
#  'schooling': 8296,
#  'possibly': 811,
#  'Kohli': 812,
#  'birth': 813,
#  'unique': 814,
#  'occurring': 816,
#  'desire': 817,
#  'Playstation': 818,
#  'themaximum': 819,
#  'bobby': 820,
#  'Framed': 821,
#  'remind': 822,
#  'wineries': 4895,
#  'groundwater': 824,
#  'Steven': 825,
#  'Pentagon': 826,
#  'Warren': 827,
#  'switchover': 828,
#  'battlefield': 829,
#  'beneficial': 830,
#  'right': 831,
#  'old': 832,
#  'crowd': 833,
#  'Hizmet': 4952,
#  'Stores': 9519,
#  'Literally': 835,
#  'mosques': 836,
#  'Soros': 837,
#  'crown': 838,
#  'System': 839,
#  'Application': 840,
#  'MLA': 14034,
#  'differentiate': 10757,
#  'Between': 842,
#  'GOI': 14035,
#  'harassment': 845,
#  'enemies': 846,
#  'consensus': 847,
#  'Tycoon': 848,
#  'sociology': 849,
#  'for': 850,
#  'bottom': 851,
#  'Quran': 852,
#  'Kylo': 9503,
#  'inhuman': 853,
#  'Gana': 16075,
#  'creative': 854,
#  'contributing': 855,
#  '370z': 15947,
#  'continue': 856,
#  'Facebook': 857,
#  'Armenia': 858,
#  'treadmill': 859,
#  'nitrate': 860,
#  'hindu': 16446,
#  'Hardness': 861,
#  'Royce': 862,
#  'Watts': 863,
#  'shakes': 864,
#  'substitutes': 865,
#  'Origins': 866,
#  'Alia': 867,
#  'dental': 868,
#  'Sentras': 869,
#  'IPv6': 12669,
#  'doesnt': 16183,
#  'Thing': 871,
#  'substituted': 872,
#  'diploid': 873,
#  'MPs': 874,
#  'starring': 875,
#  'watsapp': 876,
#  'losing': 877,
#  'memorable': 878,
#  'manufacturing': 879,
#  'Think': 880,
#  'First': 882,
#  'spaceships': 883,
#  'augmented': 12412,
#  'OS': 885,
#  'dollars': 886,
#  'citizens': 887,
#  'ranges': 13101,
#  'AVR': 888,
#  'Abhiyan': 889,
#  'SWTOR': 890,
#  'Ranbir': 891,
#  'AVI': 892,
#  'Shake': 893,
#  'Pareto': 894,
#  'slightly': 895,
#  'Targaryen': 896,
#  'raised': 897,
#  'statements': 898,
#  'Knowledge': 899,
#  'yen': 8949,
#  'Greeks': 900,
#  'honeymoon': 901,
#  'mba': 902,
#  'son': 903,
#  'respectable': 904,
#  'beings': 905,
#  'excuse': 6224,
#  'magazines': 907,
#  'raises': 908,
#  'ADHD': 909,
#  'wrap': 910,
#  'Korean': 911,
#  'reducing': 912,
#  'Melaka': 11176,
#  'Hank': 916,
#  'ISIS': 917,
#  'fabric': 918,
#  'Vichitra': 919,
#  'altitude': 920,
#  'constantly': 921,
#  'raped': 923,
#  'avail': 924,
#  'humorous': 11179,
#  'wordpress': 926,
#  'physicists': 927,
#  'greatness': 928,
#  'Poznan': 929,
#  'music': 153,
#  'ISIL': 5489,
#  'kerosene': 13493,
#  'halls': 932,
#  'launching': 933,
#  'Djokovic': 934,
#  'alloys': 935,
#  'passport': 936,
#  'offer': 937,
#  'Jabong': 938,
#  'tigers': 939,
#  'manmade': 940,
#  'annum': 14057,
#  'notifications': 943,
#  'ADMIT': 944,
#  'allopathy': 945,
#  'understandable': 946,
#  'Carbon': 8316,
#  'Chipset': 948,
#  'redundant': 13368,
#  'masquerading': 951,
#  'arrays': 952,
#  'inside': 953,
#  'myopia': 954,
#  'trash': 14593,
#  'devices': 955,
#  'County': 956,
#  'Engineering': 957,
#  'sratch': 958,
#  'nicest': 959,
#  'torturing': 960,
#  'pesos': 961,
#  'Tony': 962,
#  'panels': 963,
#  'seafood': 14061,
#  'pricing': 6101,
#  '151': 966,
#  '150': 967,
#  'juvenile': 968,
#  'proud': 10360,
#  'liberal': 970,
#  'Personal': 971,
#  'steady': 5554,
#  'MEDICAL': 973,
#  'Six': 974,
#  'Josh': 975,
#  'YOUNG': 976,
#  'proven': 977,
#  'Raipur': 978,
#  'soothe': 979,
#  'Virgin': 980,
#  'proves': 981,
#  'exist': 982,
#  'pores': 5216,
#  'decapitation': 984,
#  'tea': 14716,
#  'accounting': 985,
#  'hydrogen': 15964,
#  'correlation': 12691,
#  'dealer': 986,
#  'Sim': 987,
#  'supporters': 8322,
#  'Francisco': 989,
#  'Maya': 990,
#  'floor': 991,
#  'Immigrant': 12508,
#  'spoofing': 15291,
#  'Possible': 992,
#  'cambodia': 993,
#  'grammatical': 994,
#  'Nolan': 995,
#  'role': 996,
#  'mispelled': 997,
#  'ambitious': 998,
#  'acetaminophen': 999,
#  'findout': 1000,
#  'transgender': 1001,
#  'developers': 1002,
#  'smell': 1003,
#  'roll': 1004,
#  ...}

# %%
len(vocab)
# Out:
# 16836

# %%
data["embeddings"][]
# Out:
# {'mohini': 0,
#  'Duncan': 13910,
#  'unscientific': 1,
#  'writings': 2,
#  'Szczecin': 3,
#  'childern': 4,
#  'yellow': 5,
#  'Sugar': 6,
#  'four': 7,
#  'prefix': 8,
#  'Does': 9,
#  'Olympics': 10,
#  'spiders': 11,
#  'ornate': 66,
#  'centimeter': 14,
#  'Until': 15,
#  'aggression': 16,
#  'Foundation': 101,
#  'granting': 18,
#  'eligible': 19,
#  'electricity': 20,
#  'adviced': 21,
#  'unanswered': 22,
#  'wheeled': 23,
#  'Ronald': 24,
#  'SPI': 25,
#  'outwit': 26,
#  'Belgians': 27,
#  'Western': 28,
#  'Climbing': 30,
#  'Avada': 31,
#  'Euro': 32,
#  'sinking': 33,
#  'digit': 34,
#  'Airprint': 36,
#  'oceans': 37,
#  'Www': 11035,
#  'experimentally': 40,
#  'cobia': 41,
#  'bringing': 42,
#  'lumia': 43,
#  'Comlete': 44,
#  'differentiated': 45,
#  'basics': 46,
#  'internally': 47,
#  'scholar': 48,
#  'JNU': 49,
#  'Less': 50,
#  'wooden': 51,
#  'CGPA': 52,
#  'unblurred': 53,
#  'HDFC': 54,
#  'Nasdaq': 55,
#  'differentiates': 56,
#  'deferments': 58,
#  'Paul': 59,
#  'employee': 16355,
#  'straight': 2705,
#  'Sandy': 61,
#  'Omegle': 62,
#  'Rachel': 11042,
#  'specially': 64,
#  'tired': 65,
#  'hanging': 12,
#  'bacon': 67,
#  'pulse': 68,
#  'budget': 69,
#  '270': 70,
#  'A53': 71,
#  'cyclic': 15253,
#  'valiant': 72,
#  'sailed': 74,
#  'Pichai': 75,
#  'inanimate': 76,
#  'Sapiens': 77,
#  'errors': 79,
#  'Sapient': 80,
#  'thunder': 81,
#  'cooking': 82,
#  'contributed': 83,
#  'fingers': 84,
#  'victims': 85,
#  'gujarati': 86,
#  'ms': 12621,
#  'usenet': 87,
#  'fossil': 88,
#  'designing': 89,
#  'resilient': 90,
#  'replaced': 11048,
#  'H1B': 92,
#  'Raspberry': 93,
#  'Ichigo': 94,
#  'Presidential': 95,
#  'shocks': 96,
#  'specialist': 98,
#  'hero': 100,
#  'offenses': 10549,
#  'Freenet': 5409,
#  'Branch': 8960,
#  'splinter': 623,
#  'asteroids': 13281,
#  'brainwashed': 104,
#  'here': 105,
#  'atoms': 106,
#  'reported': 107,
#  'GRE': 108,
#  'Siliguri': 109,
#  'cult': 110,
#  'evolutionist': 111,
#  'corrections': 12843,
#  'Stephanie': 112,
#  'chaotic': 12098,
#  'kids': 113,
#  'unblocked': 114,
#  'chlorides': 115,
#  'Record': 13898,
#  'k': 117,
#  'adaptable': 16823,
#  'reports': 118,
#  'Hamas': 119,
#  'electors': 11651,
#  'tortoiseshell': 122,
#  'NOT': 123,
#  'military': 124,
#  'Hydrogen': 125,
#  'cancellation': 126,
#  'NOR': 127,
#  'Audi': 128,
#  'golden': 129,
#  'Awakens': 130,
#  'divide': 131,
#  'gluons': 132,
#  'criticise': 133,
#  'Harvey': 134,
#  'explained': 136,
#  'Three': 137,
#  'ProActiv': 138,
#  'replace': 139,
#  'psychological': 140,
#  'unix': 141,
#  'Wales': 142,
#  'Basin': 143,
#  'cocaine': 144,
#  'univ': 145,
#  'unit': 146,
#  'Nangloi': 147,
#  'derivatives': 149,
#  'cheating': 150,
#  'Sagittarius': 151,
#  'browse': 152,
#  '42': 12370,
#  '1210': 14248,
#  'Grian': 930,
#  'therefore': 154,
#  'AngularJS': 155,
#  'menthol': 15191,
#  'strike': 156,
#  'mAh': 157,
#  'Flipkart': 13905,
#  'until': 158,
#  'expiring': 159,
#  'playboy': 160,
#  'females': 161,
#  'Christine': 162,
#  'successful': 163,
#  'brings': 164,
#  'hereby': 165,
#  'underprivileged': 14807,
#  'yahoo': 167,
#  'hurt': 168,
#  '99': 169,
#  'glass': 170,
#  'reversible': 172,
#  'Tunak': 173,
#  'lord': 174,
#  '91': 175,
#  '90': 176,
#  'hole': 177,
#  'hold': 178,
#  '95': 179,
#  '94': 180,
#  '97': 181,
#  'circumstances': 182,
#  'morally': 184,
#  'Indigo': 185,
#  'pursue': 186,
#  'Text': 187,
#  'blade': 188,
#  'Luna': 189,
#  'imperialism': 11060,
#  'temperatures': 191,
#  'Malaysians': 192,
#  'concepts': 193,
#  'exhale': 194,
#  'shaving': 195,
#  'example': 196,
#  'impose': 8003,
#  'wand': 198,
#  'Quang': 1176,
#  'household': 201,
#  'artillery': 202,
#  'organized': 203,
#  'Reality': 204,
#  'currency': 205,
#  'ABAP': 206,
#  'Bike': 207,
#  'Quant': 208,
#  'want': 210,
#  'Udaipur': 211,
#  'organizer': 212,
#  'Oberon': 213,
#  'absolute': 214,
#  'Julien': 15179,
#  'LG': 215,
#  'hoc': 216,
#  'unpaid': 13913,
#  'mission': 14907,
#  'travel': 219,
#  'feature': 220,
#  'machine': 221,
#  'how': 222,
#  'methodology': 223,
#  'playback': 224,
#  'LR': 225,
#  'hop': 226,
#  'significance': 227,
#  'Krishnamurti': 229,
#  'activation': 6801,
#  'Certified': 231,
#  'Zika': 232,
#  'A': 233,
#  'tripling': 234,
#  'abstraction': 235,
#  'Bates': 236,
#  'beauty': 237,
#  'cuisine': 238,
#  'modulation': 239,
#  'typed': 240,
#  'cuss': 3325,
#  'outlawed': 241,
#  'diagram': 242,
#  'dinosaurs': 243,
#  'wrong': 244,
#  'L2': 245,
#  'destined': 246,
#  'types': 247,
#  'CFO': 248,
#  'CFL': 249,
#  'effective': 251,
#  'wins': 252,
#  'attracts': 253,
#  'Tumblr': 13912,
#  'fictional': 254,
#  'CFA': 255,
#  'baggage': 256,
#  '18th': 257,
#  'specks': 258,
#  'keeps': 259,
#  'Shimon': 260,
#  'democratic': 261,
#  'mightier': 11311,
#  'wing': 262,
#  'wind': 263,
#  'wine': 264,
#  'Monterrey': 265,
#  'Even': 5435,
#  'afterwards': 14208,
#  'feedback': 267,
#  'telecom': 268,
#  'dreamed': 269,
#  'Blackstone': 270,
#  'confederate': 8203,
#  'vary': 272,
#  'fallacies': 274,
#  'intangible': 276,
#  'Robertson': 277,
#  'activating': 279,
#  'Told': 280,
#  'PARTNERS': 281,
#  'Abbott': 282,
#  'His': 283,
#  'ligand': 284,
#  'Kearns': 285,
#  'rankings': 286,
#  'fix': 287,
#  '624': 5441,
#  'Tandon': 288,
#  'survivors': 289,
#  'Harris': 290,
#  'hidden': 291,
#  'easier': 292,
#  'ledgers': 293,
#  'blowjobs': 294,
#  'thrones': 295,
#  'enrich': 296,
#  '2030': 297,
#  'Seth': 298,
#  'Volvo': 299,
#  'commemorate': 300,
#  'effects': 301,
#  'schools': 302,
#  'silver': 303,
#  'structural': 304,
#  'rumour': 305,
#  'represents': 306,
#  'socialization': 14796,
#  'PPACA': 307,
#  'Shield': 308,
#  'APJ': 311,
#  'APK': 312,
#  'API': 313,
#  'component': 13086,
#  'averse': 315,
#  'APM': 316,
#  'addicted': 317,
#  'volcano': 318,
#  'Farsi': 319,
#  'safely': 16467,
#  'burial': 321,
#  'Falklands': 322,
#  'financial': 323,
#  'snakes': 324,
#  'woes': 325,
#  'mdm': 326,
#  'series': 327,
#  'liquids': 15445,
#  'displacement': 328,
#  'Mongolia': 329,
#  '391': 330,
#  'passwords': 11081,
#  'DCX3400': 332,
#  'laboratory': 333,
#  'rarest': 15915,
#  'ring': 335,
#  'overwrite': 336,
#  'disposed': 14521,
#  'Gustav': 337,
#  'trending': 338,
#  'Kenya': 16676,
#  'rs': 340,
#  'Retina': 341,
#  'sms': 342,
#  'angular': 5455,
#  're': 344,
#  'encourage': 345,
#  'Hercules': 8216,
#  'adapt': 347,
#  'Rabbit': 348,
#  'Entrepreneurs': 2749,
#  'size': 5456,
#  'Super': 351,
#  'foundation': 352,
#  'Word': 353,
#  'University': 355,
#  'Work': 356,
#  'surveys': 13941,
#  'managerial': 358,
#  '4620': 359,
#  'Qualcomm': 360,
#  'necessarily': 13942,
#  'Pension': 362,
#  'Mature': 363,
#  'sheet': 5459,
#  'sensors': 366,
#  'Pakistanis': 367,
#  'cornerstone': 368,
#  'r5': 369,
#  'ate': 370,
#  'Rosenberg': 371,
#  'diabetic': 372,
#  'kashmir': 373,
#  'ath': 375,
#  'heading': 8221,
#  'silicon': 377,
#  'shipped': 378,
#  'Human': 379,
#  'kingdom': 14399,
#  'repealed': 380,
#  'symbolize': 381,
#  'speeds': 382,
#  'purpose': 11089,
#  'Universities': 383,
#  'Voter': 385,
#  'Dun': 387,
#  'Duo': 388,
#  'Duc': 391,
#  'Please': 392,
#  'vitro': 393,
#  'Swg': 394,
#  'OWASP': 395,
#  'channels': 396,
#  'wash': 397,
#  'instruct': 398,
#  'IPV4': 399,
#  'Coursera': 16240,
#  'wasn': 400,
#  'clarity': 401,
#  '173': 402,
#  '172': 403,
#  '170': 404,
#  'bitten': 405,
#  'olds': 406,
#  'backlinks': 407,
#  'service': 408,
#  'lego': 409,
#  'engagement': 410,
#  'URINE': 411,
#  'Effect': 412,
#  'needed': 413,
#  'master': 414,
#  'listed': 415,
#  'hypothetical': 416,
#  'worlds': 16065,
#  'postulate': 417,
#  'legs': 418,
#  'bitter': 419,
#  'listen': 421,
#  'rectifier': 422,
#  'collapse': 423,
#  'canned': 424,
#  'cushions': 425,
#  'convention': 13954,
#  'coursera': 427,
#  'satisfaction': 14218,
#  'wisdom': 429,
#  'Date': 13955,
#  'oblongata': 432,
#  'legally': 13956,
#  'Oracle': 434,
#  'Vancouver': 16783,
#  'Daddy': 435,
#  'Deepwater': 13957,
#  'Kaine': 437,
#  'trek': 438,
#  'Code': 439,
#  'Pvt': 440,
#  'Chloe': 441,
#  'SPAM': 442,
#  'coward': 443,
#  'tree': 444,
#  'second': 445,
#  'nations': 446,
#  'shower': 447,
#  'pneumonia': 448,
#  'idle': 449,
#  'Maxis': 450,
#  'Tape': 8232,
#  'Capricorns': 453,
#  'feeling': 454,
#  'acquisition': 456,
#  'Angelo': 457,
#  'etihad': 458,
#  'entail': 459,
#  'Evasion': 460,
#  'Chicago': 461,
#  'boston': 462,
#  'Sumter': 463,
#  'spectrum': 464,
#  'Gatorade': 465,
#  'increment': 466,
#  'urinate': 467,
#  'H1b': 468,
#  'Williams': 469,
#  'CLI': 13963,
#  'Then': 471,
#  'Them': 472,
#  'recommender': 473,
#  'Portability': 7758,
#  'hymen': 475,
#  'concrete': 5428,
#  'responsible': 2777,
#  'phase': 12485,
#  'GSoC': 478,
#  'Band': 479,
#  'recommended': 480,
#  'causing': 481,
#  'absorbed': 482,
#  'Minister': 483,
#  'They': 484,
#  'brains': 5475,
#  'Ask': 486,
#  'Ash': 487,
#  'Bank': 488,
#  'Names': 489,
#  'Jones': 490,
#  'VCA': 491,
#  'committing': 492,
#  'transactions': 494,
#  'thrilled': 495,
#  'advanced': 15491,
#  'object': 496,
#  'Havarti': 8239,
#  'Rajesh': 498,
#  'metrics': 499,
#  'simplify': 500,
#  'mouth': 501,
#  'letter': 503,
#  'Gujarat': 504,
#  'gmail': 16377,
#  'thriller': 506,
#  'morality': 507,
#  'singer': 508,
#  'episode': 509,
#  'antitrust': 510,
#  'professor': 511,
#  'camp': 512,
#  'N52': 513,
#  'VCs': 515,
#  'tech': 516,
#  'euthanize': 517,
#  'mating': 518,
#  'scream': 519,
#  'came': 520,
#  'marvel': 521,
#  'saying': 522,
#  'bomb': 523,
#  'reactor': 524,
#  'Union': 525,
#  'Abdul': 526,
#  'meetings': 527,
#  'advisors': 528,
#  'sexist': 529,
#  'soluble': 530,
#  'ulcer': 532,
#  'participate': 533,
#  'lethal': 534,
#  'heckled': 535,
#  'driving': 12792,
#  'Bhopal': 537,
#  'lessons': 538,
#  'touches': 539,
#  'busy': 540,
#  'Premium': 541,
#  'BPMN': 542,
#  'menu': 543,
#  'rheostat': 545,
#  'Kedavra': 12429,
#  '1549': 546,
#  'Translator': 547,
#  'cougar': 548,
#  'theme': 549,
#  'Stripe': 550,
#  'rich': 551,
#  'rice': 553,
#  'Timor': 554,
#  'plate': 556,
#  'salespeople': 557,
#  'cubic': 12127,
#  'Jinnah': 558,
#  'umbilical': 559,
#  'foremost': 560,
#  'pocket': 561,
#  'fetish': 8253,
#  'momentums': 564,
#  'X': 565,
#  'Piece': 566,
#  'net': 8254,
#  'VoLTE': 568,
#  'increasing': 569,
#  'autistic': 570,
#  'nicely': 571,
#  'wickless': 572,
#  'ZEE': 573,
#  'Rip': 575,
#  'patch': 576,
#  'Rio': 577,
#  'Pentium': 12975,
#  'excaliber': 578,
#  'release': 580,
#  'transistors': 581,
#  'saul': 583,
#  'respond': 584,
#  'pople': 585,
#  'mandatory': 586,
#  'fair': 587,
#  'Dogg': 589,
#  'peripheral': 590,
#  'mysql': 591,
#  'Devops': 592,
#  'transferred': 5493,
#  'unexpectedly': 594,
#  'bled': 595,
#  'Mahendra': 596,
#  'DMS': 597,
#  'counries': 598,
#  'result': 599,
#  'DMV': 600,
#  'fail': 601,
#  'Olympiad': 602,
#  'Android': 603,
#  'John': 604,
#  'Dogs': 605,
#  'best': 606,
#  'reassignment': 5496,
#  'Emojis': 11121,
#  'lots': 609,
#  'Tumnus': 16568,
#  'rings': 610,
#  'Batch': 15234,
#  'stamps': 612,
#  'score': 613,
#  'Cbse': 614,
#  'yogurt': 615,
#  'Terrier': 616,
#  'pirate': 617,
#  'Advanced': 618,
#  'skimpy': 619,
#  'requisites': 620,
#  'letting': 9826,
#  'lamar': 622,
#  'men': 15993,
#  'extend': 624,
#  'nature': 625,
#  'rolled': 626,
#  'Hike': 627,
#  'personalize': 628,
#  'rides': 12956,
#  'Guwahati': 5500,
#  'eukaryotic': 630,
#  'Uncharted': 631,
#  'extent': 632,
#  'Sartre': 633,
#  'downgrade': 634,
#  'carbon': 635,
#  'debt': 636,
#  'dslr': 11127,
#  'pity': 638,
#  'patented': 639,
#  'accident': 640,
#  'country': 642,
#  'adapter': 643,
#  'enlightenment': 13211,
#  'heating': 644,
#  'demanded': 645,
#  '109': 8268,
#  'Object': 15765,
#  'planned': 647,
#  'logic': 648,
#  'ASUS': 649,
#  'login': 650,
#  'argue': 651,
#  'adapted': 652,
#  'asked': 653,
#  'PSU': 654,
#  'pre': 14001,
#  'Completeness': 658,
#  'HND': 659,
#  'Montag': 660,
#  'BCA': 661,
#  '2nd': 662,
#  'matte': 663,
#  'Ohio': 8271,
#  'pregnancy': 666,
#  'diff': 667,
#  '250': 668,
#  'angel': 5509,
#  'shouting': 11133,
#  'union': 671,
#  'Targaryens': 672,
#  'subside': 673,
#  'perchlorate': 674,
#  'economically': 12838,
#  'bothers': 675,
#  'extraction': 676,
#  'much': 677,
#  'sommelier': 678,
#  'tutorials': 679,
#  'superhuman': 680,
#  'Flowers': 681,
#  'tallest': 682,
#  'dots': 683,
#  'obese': 684,
#  'life': 685,
#  'crying': 686,
#  'spit': 687,
#  'SRE': 688,
#  'BPM': 14006,
#  'Poland': 690,
#  'worker': 691,
#  'Ketogenic': 692,
#  'snap': 11140,
#  'substance': 694,
#  'chile': 695,
#  'child': 696,
#  'fattiest': 697,
#  'worked': 698,
#  'Waffen': 5515,
#  'spin': 700,
#  'cum': 11142,
#  'Holmes': 4094,
#  'commerce': 703,
#  'adaptations': 704,
#  'presidency': 705,
#  '25M': 706,
#  'submissions': 707,
#  'technologically': 15224,
#  'professionally': 708,
#  'excited': 11143,
#  'employ': 710,
#  'calcium': 711,
#  'Spacecraft': 712,
#  'forwarder': 5978,
#  'prostrate': 715,
#  'flooding': 716,
#  'skirts': 717,
#  'remembering': 718,
#  'biotech': 719,
#  'Lindenwood': 4185,
#  'played': 721,
#  'equator': 722,
#  'FHD': 723,
#  'expat': 724,
#  'reunified': 11147,
#  'Painters': 726,
#  'player': 727,
#  'elicit': 728,
#  'Capitan': 4246,
#  'EB2': 730,
#  'levied': 731,
#  'conditioner': 4259,
#  'Nougat': 733,
#  'Riemann': 11148,
#  'hone': 734,
#  'damaged': 735,
#  'Main': 5524,
#  'severity': 737,
#  'NetSuite': 738,
#  'Python': 739,
#  'things': 740,
#  'toaster': 741,
#  'Kerman': 13002,
#  'dryness': 14017,
#  'democracies': 743,
#  'craigslist': 744,
#  '300': 11219,
#  'split': 745,
#  'babies': 746,
#  'Amelia': 747,
#  'Retriever': 4360,
#  'H3C': 750,
#  'Budapest': 751,
#  'boiled': 752,
#  'countable': 15184,
#  'qualifications': 4390,
#  'eradicate': 755,
#  'Angeles': 756,
#  'ownership': 758,
#  'wives': 760,
#  'tune': 761,
#  'intrusion': 763,
#  'matters': 11154,
#  'blowjob': 11155,
#  'EBT': 765,
#  'academic': 766,
#  'academia': 767,
#  'Goodreads': 16530,
#  'EBS': 768,
#  'quantitative': 769,
#  'corporate': 770,
#  'massaging': 771,
#  'lazer': 7302,
#  'opinions': 772,
#  'gigolo': 4548,
#  'Thank': 774,
#  'sleeps': 775,
#  'dietetics': 777,
#  'distribute': 778,
#  'sleepy': 4580,
#  'VBA': 8291,
#  'UPES': 781,
#  'financially': 782,
#  'Native': 8945,
#  'rotates': 784,
#  'portrayed': 785,
#  'previous': 786,
#  'hai': 787,
#  'enters': 788,
#  'dialogues': 789,
#  'ham': 790,
#  'dining': 14025,
#  'had': 793,
#  'Leonard': 795,
#  'XBOX': 796,
#  'Connecticut': 797,
#  'collections': 798,
#  'easy': 799,
#  'prison': 800,
#  'has': 4725,
#  'hat': 802,
#  'Apart': 803,
#  'Roadies': 804,
#  'municipal': 805,
#  'elders': 806,
#  'survival': 807,
#  'online': 5535,
#  'disagreement': 809,
#  'possible': 810,
#  'schooling': 8296,
#  'possibly': 811,
#  'Kohli': 812,
#  'birth': 813,
#  'unique': 814,
#  'occurring': 816,
#  'desire': 817,
#  'Playstation': 818,
#  'themaximum': 819,
#  'bobby': 820,
#  'Framed': 821,
#  'remind': 822,
#  'wineries': 4895,
#  'groundwater': 824,
#  'Steven': 825,
#  'Pentagon': 826,
#  'Warren': 827,
#  'switchover': 828,
#  'battlefield': 829,
#  'beneficial': 830,
#  'right': 831,
#  'old': 832,
#  'crowd': 833,
#  'Hizmet': 4952,
#  'Stores': 9519,
#  'Literally': 835,
#  'mosques': 836,
#  'Soros': 837,
#  'crown': 838,
#  'System': 839,
#  'Application': 840,
#  'MLA': 14034,
#  'differentiate': 10757,
#  'Between': 842,
#  'GOI': 14035,
#  'harassment': 845,
#  'enemies': 846,
#  'consensus': 847,
#  'Tycoon': 848,
#  'sociology': 849,
#  'for': 850,
#  'bottom': 851,
#  'Quran': 852,
#  'Kylo': 9503,
#  'inhuman': 853,
#  'Gana': 16075,
#  'creative': 854,
#  'contributing': 855,
#  '370z': 15947,
#  'continue': 856,
#  'Facebook': 857,
#  'Armenia': 858,
#  'treadmill': 859,
#  'nitrate': 860,
#  'hindu': 16446,
#  'Hardness': 861,
#  'Royce': 862,
#  'Watts': 863,
#  'shakes': 864,
#  'substitutes': 865,
#  'Origins': 866,
#  'Alia': 867,
#  'dental': 868,
#  'Sentras': 869,
#  'IPv6': 12669,
#  'doesnt': 16183,
#  'Thing': 871,
#  'substituted': 872,
#  'diploid': 873,
#  'MPs': 874,
#  'starring': 875,
#  'watsapp': 876,
#  'losing': 877,
#  'memorable': 878,
#  'manufacturing': 879,
#  'Think': 880,
#  'First': 882,
#  'spaceships': 883,
#  'augmented': 12412,
#  'OS': 885,
#  'dollars': 886,
#  'citizens': 887,
#  'ranges': 13101,
#  'AVR': 888,
#  'Abhiyan': 889,
#  'SWTOR': 890,
#  'Ranbir': 891,
#  'AVI': 892,
#  'Shake': 893,
#  'Pareto': 894,
#  'slightly': 895,
#  'Targaryen': 896,
#  'raised': 897,
#  'statements': 898,
#  'Knowledge': 899,
#  'yen': 8949,
#  'Greeks': 900,
#  'honeymoon': 901,
#  'mba': 902,
#  'son': 903,
#  'respectable': 904,
#  'beings': 905,
#  'excuse': 6224,
#  'magazines': 907,
#  'raises': 908,
#  'ADHD': 909,
#  'wrap': 910,
#  'Korean': 911,
#  'reducing': 912,
#  'Melaka': 11176,
#  'Hank': 916,
#  'ISIS': 917,
#  'fabric': 918,
#  'Vichitra': 919,
#  'altitude': 920,
#  'constantly': 921,
#  'raped': 923,
#  'avail': 924,
#  'humorous': 11179,
#  'wordpress': 926,
#  'physicists': 927,
#  'greatness': 928,
#  'Poznan': 929,
#  'music': 153,
#  'ISIL': 5489,
#  'kerosene': 13493,
#  'halls': 932,
#  'launching': 933,
#  'Djokovic': 934,
#  'alloys': 935,
#  'passport': 936,
#  'offer': 937,
#  'Jabong': 938,
#  'tigers': 939,
#  'manmade': 940,
#  'annum': 14057,
#  'notifications': 943,
#  'ADMIT': 944,
#  'allopathy': 945,
#  'understandable': 946,
#  'Carbon': 8316,
#  'Chipset': 948,
#  'redundant': 13368,
#  'masquerading': 951,
#  'arrays': 952,
#  'inside': 953,
#  'myopia': 954,
#  'trash': 14593,
#  'devices': 955,
#  'County': 956,
#  'Engineering': 957,
#  'sratch': 958,
#  'nicest': 959,
#  'torturing': 960,
#  'pesos': 961,
#  'Tony': 962,
#  'panels': 963,
#  'seafood': 14061,
#  'pricing': 6101,
#  '151': 966,
#  '150': 967,
#  'juvenile': 968,
#  'proud': 10360,
#  'liberal': 970,
#  'Personal': 971,
#  'steady': 5554,
#  'MEDICAL': 973,
#  'Six': 974,
#  'Josh': 975,
#  'YOUNG': 976,
#  'proven': 977,
#  'Raipur': 978,
#  'soothe': 979,
#  'Virgin': 980,
#  'proves': 981,
#  'exist': 982,
#  'pores': 5216,
#  'decapitation': 984,
#  'tea': 14716,
#  'accounting': 985,
#  'hydrogen': 15964,
#  'correlation': 12691,
#  'dealer': 986,
#  'Sim': 987,
#  'supporters': 8322,
#  'Francisco': 989,
#  'Maya': 990,
#  'floor': 991,
#  'Immigrant': 12508,
#  'spoofing': 15291,
#  'Possible': 992,
#  'cambodia': 993,
#  'grammatical': 994,
#  'Nolan': 995,
#  'role': 996,
#  'mispelled': 997,
#  'ambitious': 998,
#  'acetaminophen': 999,
#  'findout': 1000,
#  'transgender': 1001,
#  'developers': 1002,
#  'smell': 1003,
#  'roll': 1004,
#  ...}
